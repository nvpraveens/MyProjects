# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
location = '/content/drive/Shared drives/Faizan shared drive/Data/'

# %% [markdown]
# #### Defining couple of lists to use later

# %%
col_names=['DECK_COND_058','SUPERSTRUCTURE_COND_059','SUBSTRUCTURE_COND_060','CHANNEL_COND_061','CULVERT_COND_062'
]
rating=['9','8','7','6','5','4','<3']

# %% [markdown]
# Importing Datasets from the year 2011 to 2020, instead of all the columns for simplicity importing only required columns

# %%
FL_2020=pd.read_excel(location+"FL_2020.xlsx")
FL_2019=pd.read_excel(location+"FL_2019.xlsx")
FL_2018=pd.read_excel(location+"FL_2018.xlsx")
FL_2017=pd.read_excel(location+"FL_2017.xlsx")
FL_2016=pd.read_excel(location+"FL_2016.xlsx")
FL_2015=pd.read_excel(location+"FL_2015.xlsx")
FL_2014=pd.read_excel(location+"FL_2014.xlsx")
FL_2013=pd.read_excel(location+"FL_2013.xlsx")
FL_2012=pd.read_excel(location+"FL_2012.xlsx")
FL_2011=pd.read_excel(location+"FL_2011.xlsx")

# %%
FL_2020.shape
# Out:
# (12592, 123)

# %%
FL_2019.shape
# Out:
# (12518, 123)

# %%
FL_2018.shape
# Out:
# (12435, 137)

# %%
FL_2017.shape
# Out:
# (12355, 137)

# %%
FL_2016.shape
# Out:
# (12313, 135)

# %%
FL_2015.shape
# Out:
# (12198, 134)

# %%
FL_2014.shape
# Out:
# (12137, 134)

# %%
FL_2013.shape
# Out:
# (12070, 134)

# %%
FL_2012.shape
# Out:
# (11982, 134)

# %%
FL_2011.shape
# Out:
# (11986, 134)

# %% [markdown]
# Defining a Rating column in each dataframe by taking the minimum value of the possible ratings

# %%
# FL_2020
# fig_dims = (12, 8)
# fig, ax = plt.subplots(figsize=fig_dims)
# sns.heatmap(FL_2020.corr(), ax=ax)
# plt.show()

# %%
# abs(FL_2020.corr()["Rating_2020"]).sort_values(ascending = False)[1:10]

# %%
# abs(FL_2020.corr()["Rating_2020"][abs(FL_2020.corr()["Rating_2020"])>=0.3].drop('Rating_2020')).index.tolist()

# %%
FL_2020.replace('N', np.NaN, inplace=True)
FL_2020['Rating_2020']=FL_2020[col_names].min(axis=1,skipna=True)
FL_2020.drop(FL_2020.index[FL_2020['Rating_2020']<=0], inplace = True)
FL_2020 = FL_2020.drop(col_names,1)
FL_2020.set_index('STRUCTURE_NUMBER_008')
FL_2020
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  DECK_AREA  Rating_2020
# 0                  12                10001  ...     191.80          6.0
# 1                  12                10003  ...     113.36          6.0
# 2                  12                10006  ...      69.58          7.0
# 3                  12                10007  ...     356.46          7.0
# 4                  12                10008  ...     385.52          7.0
# ...               ...                  ...  ...        ...          ...
# 12587              12      AFFLKYJM00003    ...      55.90          7.0
# 12588              12      AFFLNVZR00001    ...     113.40          6.0
# 12589              12      AFFLNVZR00002    ...     138.18          7.0
# 12590              12      AFFLXLWU18169    ...      58.00          5.0
# 12591              12      CEPSAJFL-ORTONA  ...     185.50          7.0
#
# [12590 rows x 119 columns]

# %%
# FL_2020.columns.to_list()

# %%
# corr=FL_2020.corr().abs()
# sns.heatmap(FL_2020.corr(), annot=True)
# plt.show()

# %%
FL_2019.replace('N', np.NaN, inplace=True)
FL_2019['Rating_2019']=FL_2019[col_names].min(axis=1,skipna=True)
FL_2019.drop(FL_2019.index[FL_2019['Rating_2019']<=0], inplace = True)
FL_2019 = FL_2019.drop(col_names,1)
FL_2019.set_index('STRUCTURE_NUMBER_008')
FL_2019
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  DECK_AREA  Rating_2019
# 0                  12                10001  ...     178.10          6.0
# 1                  12                10003  ...     113.36          7.0
# 2                  12                10006  ...      69.58          7.0
# 3                  12                10007  ...     356.46          7.0
# 4                  12                10008  ...     385.52          7.0
# ...               ...                  ...  ...        ...          ...
# 12513              12      AFFLKYJM00003    ...      56.33          7.0
# 12514              12      AFFLNVZR00001    ...     113.40          7.0
# 12515              12      AFFLNVZR00002    ...     138.18          7.0
# 12516              12      AFFLXLWU18169    ...      58.00          5.0
# 12517              12      CEPSAJFL-ORTONA  ...     185.50          7.0
#
# [12517 rows x 119 columns]

# %%
FL_2018.replace('N', np.NaN, inplace=True)
FL_2018['Rating_2018']=FL_2018[col_names].min(axis=1,skipna=True)
FL_2018.drop(FL_2018.index[FL_2018['Rating_2018']<=0], inplace = True)
FL_2018 = FL_2018.drop(col_names,1)
FL_2018.set_index('STRUCTURE_NUMBER_008')
FL_2018
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...   CAT29  Rating_2018
# 0                  12                10001  ...  149.10          7.0
# 1                  12                10003  ...  113.36          7.0
# 2                  12                10006  ...   69.58          7.0
# 3                  12                10007  ...  356.46          7.0
# 4                  12                10008  ...  385.52          7.0
# ...               ...                  ...  ...     ...          ...
# 12430              12      AFFLFTFA12299    ...  110.08          5.0
# 12431              12      AFFLNVZR00001    ...  113.40          7.0
# 12432              12      AFFLNVZR00002    ...  138.18          7.0
# 12433              12      AFFLXLWU18169    ...   58.00          5.0
# 12434              12      CEPSAJFL-ORTONA  ...  185.50          7.0
#
# [12433 rows x 133 columns]

# %%
FL_2017.replace('N', np.NaN, inplace=True)
FL_2017['Rating_2017']=FL_2017[col_names].min(axis=1,skipna=True)
FL_2017.drop(FL_2017.index[FL_2017['Rating_2017']<=0], inplace = True)
FL_2017 = FL_2017.drop(col_names,1)
FL_2017
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...   CAT29  Rating_2017
# 0                  12                10001  ...  149.10          7.0
# 1                  12                10003  ...  113.36          7.0
# 2                  12                10006  ...   69.58          7.0
# 3                  12                10007  ...  356.46          7.0
# 4                  12                10008  ...  385.52          7.0
# ...               ...                  ...  ...     ...          ...
# 12350              12      AFFLFTFA12299    ...  110.08          6.0
# 12351              12      AFFLNVZR00001    ...  113.40          7.0
# 12352              12      AFFLNVZR00002    ...  138.18          7.0
# 12353              12      AFFLXLWU18169    ...   58.00          5.0
# 12354              12      CEPSAJFL-ORTONA  ...  185.50          7.0
#
# [12352 rows x 133 columns]

# %%
FL_2016.replace('N', np.NaN, inplace=True)
FL_2016['Rating_2016']=FL_2016[col_names].min(axis=1,skipna=True)
FL_2016.drop(FL_2016.index[FL_2016['Rating_2016']<=0], inplace = True)
FL_2016 = FL_2016.drop(col_names,1)
FL_2016
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  CAT10  Rating_2016
# 0                  12                10001  ...      G          7.0
# 1                  12                10003  ...      G          7.0
# 2                  12                10006  ...      G          7.0
# 3                  12                10007  ...      G          7.0
# 4                  12                10008  ...      G          7.0
# ...               ...                  ...  ...    ...          ...
# 12308              12      AFFLFTFA12299    ...      F          6.0
# 12309              12      AFFLNVZR00001    ...      G          7.0
# 12310              12      AFFLNVZR00002    ...      G          7.0
# 12311              12      AFFLXLWU18169    ...      G          9.0
# 12312              12      CEPSAJFL-ORTONA  ...      G          7.0
#
# [12310 rows x 131 columns]

# %%
FL_2015.replace('N', np.NaN, inplace=True)
FL_2015['Rating_2015']=FL_2015[col_names].min(axis=1,skipna=True)
FL_2015.drop(FL_2015.index[FL_2015['Rating_2015']<=0], inplace = True)
FL_2015 = FL_2015.drop(col_names,1)
FL_2015.set_index('STRUCTURE_NUMBER_008')
FL_2015
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  STATUS_NO_10YR_RULE  Rating_2015
# 0                  12                10001  ...                    0          7.0
# 1                  12                10003  ...                    0          7.0
# 2                  12                10006  ...                    0          7.0
# 3                  12                10007  ...                    2          7.0
# 4                  12                10008  ...                    0          7.0
# ...               ...                  ...  ...                  ...          ...
# 12193              12      AFFLFTFA12299    ...                    0          6.0
# 12194              12      AFFLNVZR00001    ...                    0          7.0
# 12195              12      AFFLNVZR00002    ...                    0          5.0
# 12196              12      AFFLXLWU18169    ...                    0          9.0
# 12197              12      CEPSAJFL-ORTONA  ...                    0          7.0
#
# [12196 rows x 130 columns]

# %%
FL_2014.replace('N', np.NaN, inplace=True)
FL_2014['Rating_2014']=FL_2014[col_names].min(axis=1,skipna=True)
FL_2014.drop(FL_2014.index[FL_2014['Rating_2014']<=0], inplace = True)
FL_2014 = FL_2014.drop(col_names,1)
FL_2014.set_index('STRUCTURE_NUMBER_008')
FL_2014
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  STATUS_NO_10YR_RULE  Rating_2014
# 0                  12                10001  ...                    0          7.0
# 1                  12                10003  ...                    0          7.0
# 2                  12                10006  ...                    0          7.0
# 3                  12                10007  ...                    2          7.0
# 4                  12                10008  ...                    0          7.0
# ...               ...                  ...  ...                  ...          ...
# 12132              12      AFFLFTFA12299    ...                    0          7.0
# 12133              12      AFFLNVZR00001    ...                    0          7.0
# 12134              12      AFFLNVZR00002    ...                    0          5.0
# 12135              12      AFFLXLWU18169    ...                    0          9.0
# 12136              12      CEPSAJFL-ORTONA  ...                    0          7.0
#
# [12135 rows x 130 columns]

# %%
FL_2013.replace('N', np.NaN, inplace=True)
FL_2013['Rating_2013']=FL_2013[col_names].min(axis=1,skipna=True)
FL_2013.drop(FL_2013.index[FL_2013['Rating_2013']<=0], inplace = True)
FL_2013 = FL_2013.drop(col_names,1)
FL_2013.set_index('STRUCTURE_NUMBER_008')
FL_2013
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  STATUS_NO_10YR_RULE  Rating_2013
# 0                  12                10001  ...                    0          7.0
# 1                  12                10003  ...                    0          7.0
# 2                  12                10006  ...                    0          7.0
# 3                  12                10007  ...                    2          7.0
# 4                  12                10008  ...                    0          7.0
# ...               ...                  ...  ...                  ...          ...
# 12065              12      AFFLFTFA12299    ...                    0          7.0
# 12066              12      AFFLNVZR00001    ...                    0          7.0
# 12067              12      AFFLNVZR00002    ...                    0          5.0
# 12068              12      AFFLXLWU18169    ...                    0          9.0
# 12069              12      CEPSAJFL-ORTONA  ...                    0          7.0
#
# [12070 rows x 130 columns]

# %%
FL_2012.replace('N', np.NaN, inplace=True)
FL_2012['Rating_2012']=FL_2012[col_names].min(axis=1,skipna=True)
FL_2012.drop(FL_2012.index[FL_2012['Rating_2012']<=0], inplace = True)
FL_2012 = FL_2012.drop(col_names,1)
FL_2012.set_index('STRUCTURE_NUMBER_008')
FL_2012
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  STATUS_NO_10YR_RULE  Rating_2012
# 0                  12                10001  ...                    0          7.0
# 1                  12                10003  ...                    0          7.0
# 2                  12                10004  ...                    2          5.0
# 3                  12                10006  ...                    0          7.0
# 4                  12                10007  ...                    2          7.0
# ...               ...                  ...  ...                  ...          ...
# 11977              12      AFFLFTFA12248    ...                    0          6.0
# 11978              12      AFFLNVZR00001    ...                    0          7.0
# 11979              12      AFFLNVZR00002    ...                    0          5.0
# 11980              12      AFFLXLWU18169    ...                    0          9.0
# 11981              12      CEPSAJFL-ORTONA  ...                    0          7.0
#
# [11980 rows x 130 columns]

# %%
FL_2011.replace('N', np.NaN, inplace=True)
FL_2011['Rating_2011']=FL_2011[col_names].min(axis=1,skipna=True)
FL_2011.drop(FL_2011.index[FL_2011['Rating_2011']<=0], inplace = True)
FL_2011 = FL_2011.drop(col_names,1)
FL_2011.set_index('STRUCTURE_NUMBER_008')
FL_2011
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  STATUS_NO_10YR_RULE  Rating_2011
# 0                  12                10001  ...                    0          7.0
# 1                  12                10003  ...                    0          7.0
# 2                  12                10004  ...                    2          5.0
# 3                  12                10006  ...                    0          7.0
# 4                  12                10007  ...                    2          7.0
# ...               ...                  ...  ...                  ...          ...
# 11981              12      AFFLFTFA12248    ...                    0          6.0
# 11982              12      AFFLNVZR00001    ...                    0          7.0
# 11983              12      AFFLNVZR00002    ...                    0          5.0
# 11984              12      AFFLXLWU18169    ...                    2          9.0
# 11985              12      CEPSAJFL-ORTONA  ...                    0          7.0
#
# [11984 rows x 130 columns]

# %% [markdown]
# Creating a Master sheet with all the ratings from 2011 to 2020

# %%
rec_c=set(FL_2011.columns) & set(FL_2012.columns) & set(FL_2013.columns) & set(FL_2014.columns) & set(FL_2015.columns) & set(FL_2016.columns) & set(FL_2017.columns) & set(FL_2018.columns) & set(FL_2019.columns) & set(FL_2020.columns)
col=list(rec_c)
col
# Out:
# ['FEATURES_DESC_006A',
#  'INVENTORY_RATING_066',
#  'FEDERAL_LANDS_105',
#  'HISTORY_037',
#  'MAX_SPAN_LEN_MT_048',
#  'FRACTURE_092A',
#  'RIGHT_CURB_MT_050B',
#  'PARALLEL_STRUCTURE_101',
#  'PIER_PROTECTION_111',
#  'TOTAL_IMP_COST_096',
#  'STRAHNET_HIGHWAY_100',
#  'OPR_RATING_METH_063',
#  'IMP_LEN_MT_076',
#  'COUNTY_CODE_003',
#  'SERVICE_UND_042B',
#  'APPR_ROAD_EVAL_072',
#  'VERT_CLR_UND_REF_054A',
#  'HIGHWAY_DISTRICT_002',
#  'APPR_WIDTH_MT_032',
#  'WORK_PROPOSED_075A',
#  'UNDCLRENCE_EVAL_069',
#  'LRS_INV_ROUTE_013A',
#  'WORK_DONE_BY_075B',
#  'STRUCTURAL_EVAL_067',
#  'KILOPOINT_011',
#  'APPR_RAIL_END_036D',
#  'OWNER_022',
#  'PLACE_CODE_004',
#  'MEDIAN_CODE_033',
#  'TRAFFIC_DIRECTION_102',
#  'TRANSITIONS_036B',
#  'ROUTE_NUMBER_005D',
#  'OTHER_STATE_PCNT_098B',
#  'OPEN_CLOSED_POSTED_041',
#  'ROADWAY_IMP_COST_095',
#  'INV_RATING_METH_065',
#  'SCOUR_CRITICAL_113',
#  'UNDWATER_LAST_DATE_093B',
#  'TEMP_STRUCTURE_103',
#  'BRIDGE_IMP_COST_094',
#  'TRAFFIC_LANES_ON_028A',
#  'ROADWAY_WIDTH_MT_051',
#  'VERT_CLR_UND_054B',
#  'HIGHWAY_SYSTEM_104',
#  'STATE_CODE_001',
#  'VERT_CLR_OVER_MT_053',
#  'YEAR_ADT_030',
#  'SPEC_INSPECT_092C',
#  'YEAR_BUILT_027',
#  'STRUCTURE_TYPE_043B',
#  'LONG_017',
#  'NAV_VERT_CLR_MT_039',
#  'DECK_GEOMETRY_EVAL_068',
#  'NAVIGATION_038',
#  'FED_AGENCY',
#  'DEGREES_SKEW_034',
#  'SPEC_LAST_DATE_093C',
#  'APPR_SPANS_046',
#  'YEAR_OF_IMP_097',
#  'OTHER_STATE_CODE_098A',
#  'LOCATION_009',
#  'FRACTURE_LAST_DATE_093A',
#  'POSTING_EVAL_070',
#  'LEFT_LAT_UND_MT_056',
#  'UNDWATER_LOOK_SEE_092B',
#  'APPR_RAIL_036C',
#  'APPR_TYPE_044B',
#  'NAV_HORR_CLR_MT_040',
#  'DECK_PROTECTION_108C',
#  'MEMBRANE_TYPE_108B',
#  'FUTURE_ADT_114',
#  'DIRECTION_005E',
#  'HORR_CLR_MT_047',
#  'INSPECT_FREQ_MONTHS_091',
#  'APPR_KIND_044A',
#  'LAT_UND_MT_055B',
#  'SERVICE_LEVEL_005C',
#  'BASE_HWY_NETWORK_012',
#  'LAT_016',
#  'OTHR_STATE_STRUC_NO_099',
#  'LEFT_CURB_MT_050A',
#  'RAILINGS_036A',
#  'DECK_WIDTH_MT_052',
#  'BRIDGE_LEN_IND_112',
#  'RECORD_TYPE_005A',
#  'ADT_029',
#  'FACILITY_CARRIED_007',
#  'STRUCTURE_FLARED_035',
#  'LAT_UND_REF_055A',
#  'OPERATING_RATING_064',
#  'YEAR_RECONSTRUCTED_106',
#  'DETOUR_KILOS_019',
#  'DECK_STRUCTURE_TYPE_107',
#  'STRUCTURE_KIND_043A',
#  'YEAR_OF_FUTURE_ADT_115',
#  'SURFACE_TYPE_108A',
#  'STRUCTURE_NUMBER_008',
#  'MIN_VERT_CLR_010',
#  'PERCENT_ADT_TRUCK_109',
#  'MAIN_UNIT_SPANS_045',
#  'TRAFFIC_LANES_UND_028B',
#  'FUNCTIONAL_CLASS_026',
#  'WATERWAY_EVAL_071',
#  'STRUCTURE_LEN_MT_049',
#  'ROUTE_PREFIX_005B',
#  'SERVICE_ON_042A',
#  'SUBROUTE_NO_013B',
#  'NATIONAL_NETWORK_110',
#  'MAINTENANCE_021',
#  'TOLL_020',
#  'MIN_NAV_CLR_MT_116',
#  'DESIGN_LOAD_031',
#  'DATE_OF_INSPECT_090',
#  'CRITICAL_FACILITY_006B']

# %%
Master= pd.concat([FL_2011,FL_2012['Rating_2012'],FL_2013['Rating_2013'],FL_2014['Rating_2014'],FL_2015['Rating_2015'],FL_2016['Rating_2016'],FL_2017['Rating_2017'],FL_2018['Rating_2018'],FL_2019['Rating_2019'],FL_2020['Rating_2020']], axis=1)

# %%
nd =Master

# %%
Master.isna().sum()
# Out:
# STATE_CODE_001          608
# STRUCTURE_NUMBER_008    608
# RECORD_TYPE_005A        608
# ROUTE_PREFIX_005B       608
# SERVICE_LEVEL_005C      608
#                        ...
# Rating_2016             283
# Rating_2017             241
# Rating_2018             160
# Rating_2019              75
# Rating_2020               2
# Length: 139, dtype: int64

# %%
Master.isnull().sum(axis = 1)
# Out:
# 0         33
# 1         31
# 2         23
# 3         31
# 4         25
#         ...
# 12587    138
# 12588    138
# 12589    138
# 12590    138
# 12591    138
# Length: 12592, dtype: int64

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(Master.corr(), ax=ax)
plt.show()
# Out:
# <div id='930ee8d9-0b2f-469c-9662-b7404d7b9181'></div>

# %%
Master['Det_Rate']=(Master['Rating_2020']-Master['Rating_2011'])/10

# %%
Master.dropna(subset=['Det_Rate'])
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  ...  Rating_2020  Det_Rate
# 0                12.0                10001  ...          6.0      -0.1
# 1                12.0                10003  ...          6.0      -0.1
# 2                12.0                10004  ...          7.0       0.2
# 3                12.0                10006  ...          7.0       0.0
# 4                12.0                10007  ...          7.0       0.0
# ...               ...                  ...  ...          ...       ...
# 11981            12.0      AFFLFTFA12248    ...          7.0       0.1
# 11982            12.0      AFFLNVZR00001    ...          6.0      -0.1
# 11983            12.0      AFFLNVZR00002    ...          7.0       0.2
# 11984            12.0      AFFLXLWU18169    ...          8.0      -0.1
# 11985            12.0      CEPSAJFL-ORTONA  ...          8.0       0.1
#
# [11980 rows x 140 columns]

# %%
abs(Master.corr()["Det_Rate"][abs(Master.corr()["Det_Rate"])>0.5].drop('Det_Rate')).index.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['OTHER_STATE_CODE_098A', 'Rating_2011', 'Rating_2020'], dtype='object')>

# %%
corrmat = Master.corr()
corrdf = corrmat.where(np.triu(np.ones(corrmat.shape), k=1).astype(bool))
corrdf = corrdf.unstack().reset_index()
corrdf.columns = ['var1', 'var2', 'Correlation']
corrdf.dropna(subset = ['Correlation'], inplace = True)
corrdf['Correlation'] = round(corrdf['Correlation'], 2)
matrix= corrdf.sort_values(by = 'Correlation', ascending = False).head(30)
print("Correlation Coefficient (descending order):\n", matrix)
# Out:
# Correlation Coefficient (descending order):
#                            var1                     var2  Correlation
# 6842       INV_RATING_METH_065      OPR_RATING_METH_063         0.99
# 10604           FUTURE_ADT_114                  ADT_029         0.98
# 6031         DECK_WIDTH_MT_052     ROADWAY_WIDTH_MT_051         0.98
# 2203                 OWNER_022          MAINTENANCE_021         0.97
# 8349   UNDWATER_LAST_DATE_093B      DATE_OF_INSPECT_090         0.95
# 11946      STATUS_NO_10YR_RULE    STATUS_WITH_10YR_RULE         0.93
# 8234   FRACTURE_LAST_DATE_093A      DATE_OF_INSPECT_090         0.90
# 10207     DECK_PROTECTION_108C       MEMBRANE_TYPE_108B         0.88
# 6958      INVENTORY_RATING_066     OPERATING_RATING_064         0.87
# 2890              YEAR_ADT_030                 LONG_017         0.87
# 8467       SPEC_LAST_DATE_093C  UNDWATER_LAST_DATE_093B         0.85
# 13188                 Det_Rate    OTHER_STATE_CODE_098A         0.85
# 3012         APPR_WIDTH_MT_032    TRAFFIC_LANES_ON_028A         0.84
# 8464       SPEC_LAST_DATE_093C      DATE_OF_INSPECT_090         0.83
# 11347          DTL_TYPE_OF_IMP          YEAR_OF_IMP_097         0.83
# 1739                  LONG_017                  LAT_016         0.82
# 8351   UNDWATER_LAST_DATE_093B  FRACTURE_LAST_DATE_093A         0.81
# 4291       NAV_HORR_CLR_MT_040      NAV_VERT_CLR_MT_039         0.76
# 13073              Rating_2020    OTHER_STATE_CODE_098A         0.76
# 9001     OTHER_STATE_CODE_098A         TRANSITIONS_036B         0.73
# 4175       NAV_VERT_CLR_MT_039           NAVIGATION_038         0.72
# 3827        APPR_RAIL_END_036D           APPR_RAIL_036C         0.72
# 13223                 Det_Rate              Rating_2020         0.72
# 8814        TOTAL_IMP_COST_096      BRIDGE_IMP_COST_094         0.71
# 10432     NATIONAL_NETWORK_110       HIGHWAY_SYSTEM_104         0.70
# 4290       NAV_HORR_CLR_MT_040           NAVIGATION_038         0.69
# 11923      STATUS_NO_10YR_RULE    OTHER_STATE_CODE_098A         0.68
# 5312           HORR_CLR_MT_047    TRAFFIC_LANES_ON_028A         0.68
# 10606           FUTURE_ADT_114        APPR_WIDTH_MT_032         0.67
# 9441        HIGHWAY_SYSTEM_104     BASE_HWY_NETWORK_012         0.67

# %%
nd = nd.fillna(0)
rating =['Rating_2011','Rating_2012','Rating_2013','Rating_2014','Rating_2015','Rating_2016','Rating_2017','Rating_2018','Rating_2019','Rating_2020']
nd[rating].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12592 entries, 0 to 12591
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rating_2011  12592 non-null  float64
#  1   Rating_2012  12592 non-null  float64
#  2   Rating_2013  12592 non-null  float64
#  3   Rating_2014  12592 non-null  float64
#  4   Rating_2015  12592 non-null  float64
#  5   Rating_2016  12592 non-null  float64
#  6   Rating_2017  12592 non-null  float64
#  7   Rating_2018  12592 non-null  float64
#  8   Rating_2019  12592 non-null  float64
#  9   Rating_2020  12592 non-null  float64
# dtypes: float64(10)
# memory usage: 1.1 MB

# %%
#affected by variables
pd.DataFrame(nd.corr())[rating]
# Out:
#                     Rating_2011  Rating_2012  ...  Rating_2019  Rating_2020
# STATE_CODE_001         0.850850     0.849059  ...     0.153730    -0.019803
# RECORD_TYPE_005A       0.850850     0.849059  ...     0.153730    -0.019803
# ROUTE_PREFIX_005B      0.272633     0.295423  ...     0.054789    -0.017082
# SERVICE_LEVEL_005C     0.234395     0.209187  ...     0.066564     0.047181
# DIRECTION_005E         0.063167     0.057079  ...     0.035707     0.025755
# ...                         ...          ...  ...          ...          ...
# Rating_2016            0.456433     0.461632  ...     0.266573     0.084166
# Rating_2017            0.400731     0.405210  ...     0.305998     0.109634
# Rating_2018            0.284603     0.278579  ...     0.363402     0.162111
# Rating_2019            0.144190     0.148014  ...     1.000000     0.193959
# Rating_2020            0.003763     0.016003  ...     0.193959     1.000000
#
# [114 rows x 10 columns]

# %%
nd.shape
# Out:
# (12592, 139)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier


time_ = nd.iloc[:,-10:]

x = time_.iloc[:,-10:-1]
y = time_.iloc[:,-1]
reg = DecisionTreeClassifier()#LinearRegression()
reg.fit(x,y)
c_=2021
for i in range(10):
  reg.fit(time_.iloc[:,-10:-1],time_.iloc[:,-1])
  pred = reg.predict(time_.iloc[:,-9:])
  time_['Rating_'+str(c_)]= pred
  c_+=1
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2020
# Feature names seen at fit time, yet now missing:
# - Rating_2011
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2021
# Feature names seen at fit time, yet now missing:
# - Rating_2012
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2022
# Feature names seen at fit time, yet now missing:
# - Rating_2013
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2023
# Feature names seen at fit time, yet now missing:
# - Rating_2014
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2024
# Feature names seen at fit time, yet now missing:
# - Rating_2015
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2025
# Feature names seen at fit time, yet now missing:
# - Rating_2016
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2026
# Feature names seen at fit time, yet now missing:
# - Rating_2017
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2027
# Feature names seen at fit time, yet now missing:
# - Rating_2018
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2028
# Feature names seen at fit time, yet now missing:
# - Rating_2019
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Rating_2029
# Feature names seen at fit time, yet now missing:
# - Rating_2020
#
#   warnings.warn(message, FutureWarning)

# %%
for i in time_.columns[-5:]:
  print('predictions : ' ,i)
  print(time_[i].value_counts())
# Out:
# predictions :  Rating_2026
# 7.0    6164
# 6.0    3520
# 5.0    1337
# 4.0     675
# 8.0     646
# 3.0     116
# 9.0      88
# 2.0      35
# 0.0       6
# 1.0       5
# Name: Rating_2026, dtype: int64
# predictions :  Rating_2027
# 7.0    6273
# 6.0    3415
# 5.0    1393
# 4.0     703
# 8.0     585
# 3.0     102
# 9.0      82
# 2.0      33
# 1.0       4
# 0.0       2
# Name: Rating_2027, dtype: int64
# predictions :  Rating_2028
# 7.0    6267
# 6.0    3371
# 5.0    1446
# 4.0     651
# 8.0     637
# 3.0     100
# 9.0      77
# 2.0      34
# 0.0       8
# 1.0       1
# Name: Rating_2028, dtype: int64
# predictions :  Rating_2029
# 7.0    6034
# 6.0    3443
# 5.0    1483
# 4.0     734
# 8.0     673
# 3.0     105
# 9.0      85
# 2.0      30
# 0.0       5
# Name: Rating_2029, dtype: int64
# predictions :  Rating_2030
# 7.0    6135
# 6.0    3266
# 5.0    1514
# 4.0     776
# 8.0     693
# 3.0      96
# 9.0      93
# 2.0      13
# 0.0       6
# Name: Rating_2030, dtype: int64

# %%
for i in time_.columns[:5]:
  print('years : ' ,i)
  print(time_[i].value_counts())
# Out:
# years :  Rating_2011
# 7.0    6770
# 6.0    2922
# 5.0     968
# 8.0     929
# 0.0     610
# 4.0     249
# 9.0      78
# 3.0      54
# 2.0      12
# Name: Rating_2011, dtype: int64
# years :  Rating_2012
# 7.0    6782
# 6.0    2977
# 5.0     993
# 8.0     873
# 0.0     613
# 4.0     225
# 9.0      64
# 3.0      50
# 2.0      13
# 1.0       2
# Name: Rating_2012, dtype: int64
# years :  Rating_2013
# 7.0    6816
# 6.0    3016
# 5.0    1018
# 8.0     861
# 0.0     523
# 4.0     216
# 9.0      81
# 3.0      46
# 2.0      12
# 1.0       3
# Name: Rating_2013, dtype: int64
# years :  Rating_2014
# 7.0    6788
# 6.0    3103
# 5.0    1032
# 8.0     884
# 0.0     458
# 4.0     201
# 9.0      76
# 3.0      40
# 2.0       8
# 1.0       2
# Name: Rating_2014, dtype: int64
# years :  Rating_2015
# 7.0    6721
# 6.0    3163
# 5.0    1079
# 8.0     894
# 0.0     397
# 4.0     226
# 9.0      64
# 3.0      39
# 2.0       9
# Name: Rating_2015, dtype: int64

# %%
time_.head()
# Out:
#    Rating_2011  Rating_2012  Rating_2013  ...  Rating_2028  Rating_2029  Rating_2030
# 0          7.0          7.0          7.0  ...          7.0          6.0          7.0
# 1          7.0          7.0          7.0  ...          7.0          7.0          7.0
# 2          5.0          5.0          7.0  ...          7.0          7.0          7.0
# 3          7.0          7.0          7.0  ...          7.0          7.0          7.0
# 4          7.0          7.0          7.0  ...          7.0          7.0          7.0
#
# [5 rows x 20 columns]
